# %%
import pickle
import pandas as pd

# %%
df1 = pickle.load(open("all_linkedin_worldwide_datascience_jobs_with_salary.pkl", "rb"))
df2 = pickle.load(open("all_gd_company_infos.pkl", "rb"))

# %%
jobs = df1.merge(df2, how = 'left', on = 'company')

# %%
jobs
# Out:
#                        company                        title  \
# 0                       TikTok  Data Scientist - TikTok Ads
# 1                        Tesla               Data Scientist
# 2                        Tesla               Data Scientist
# 3                     Facebook      Data Scientist, Finance
# 4                     Facebook      Data Scientist, Finance
# ..                         ...                          ...
# 484  Amazon Web Services (AWS)               Data Scientist
# 485                PlayStation        Data Scientist Intern
# 486            Lockheed Martin               Data Scientist
# 487            Lockheed Martin               Data Scientist
# 488            Lockheed Martin               Data Scientist
#
#               location                                               href  \
# 0    Mountain View, CA  https://www.linkedin.com/jobs/view/2148228403/...
# 1          Fremont, CA  https://www.linkedin.com/jobs/view/2147874276/...
# 2          Fremont, CA  https://www.linkedin.com/jobs/view/2147874276/...
# 3       Menlo Park, CA  https://www.linkedin.com/jobs/view/2016420647/...
# 4       Menlo Park, CA  https://www.linkedin.com/jobs/view/2016420647/...
# ..                 ...                                                ...
# 484    Jersey City, NJ  https://www.linkedin.com/jobs/view/1991684708/...
# 485      San Mateo, CA  https://www.linkedin.com/jobs/view/2149521530/...
# 486        Shelton, CT  https://www.linkedin.com/jobs/view/2014612647/...
# 487        Shelton, CT  https://www.linkedin.com/jobs/view/2014612647/...
# 488        Shelton, CT  https://www.linkedin.com/jobs/view/2014612647/...
#
#           salary                                        description  \
# 0    $144,000/yr  TikTok is the leading destination for short-fo...
# 1    $107,000/yr  THE ROLE\n\nTesla's mission is to accelerate t...
# 2    $107,000/yr  THE ROLE\n\nTesla's mission is to accelerate t...
# 3    $150,000/yr  Facebook's mission is to give people the power...
# 4    $150,000/yr  Facebook's mission is to give people the power...
# ..           ...                                                ...
# 484  $134,000/yr  Description\n\nExcited by using massive amount...
# 485  $139,000/yr  PlayStation isn’t just the Best Place to Play ...
# 486  $112,000/yr  Description:Performs exploratory research and ...
# 487  $112,000/yr  Description:Performs exploratory research and ...
# 488  $112,000/yr  Description:Performs exploratory research and ...
#
#                                                 skills  \
# 0                                                   []
# 1    [ Contribute on all the stages of Data Science...
# 2    [ Contribute on all the stages of Data Science...
# 3    [Apply your expertise in quantitative analysis...
# 4    [Apply your expertise in quantitative analysis...
# ..                                                 ...
# 484  [ Understand the customer’s business need and ...
# 485  [Building models to predict customer behaviors...
# 486                                                 []
# 487                                                 []
# 488                                                 []
#
#                                                details         headquarters  \
# 0                                                                        -1
# 1    Seniority Level\nEntry level\nIndustry\nAutomo...   Palo Alto, CA (US)
# 2    Seniority Level\nEntry level\nIndustry\nAutomo...   Palo Alto, CA (US)
# 3    Industry\nInternet\nEmployment Type\nFull-time...  Menlo Park, CA (US)
# 4    Industry\nInternet\nEmployment Type\nFull-time...  Menlo Park, CA (US)
# ..                                                 ...                  ...
# 484  Industry\nComputer Software Information Techno...     Seattle, WA (US)
# 485  Seniority Level\nInternship\nIndustry\nCompute...   San Mateo, CA (US)
# 486  Seniority Level\nEntry level\nIndustry\nConstr...    Bethesda, MD (US)
# 487  Seniority Level\nEntry level\nIndustry\nConstr...    Bethesda, MD (US)
# 488  Seniority Level\nEntry level\nIndustry\nConstr...    Bethesda, MD (US)
#
#                 company_size             company_type  \
# 0                         -1                       -1
# 1           10000+ employees  Company - Public (TSLA)
# 2           10000+ employees  Company - Public (TSLA)
# 3           10000+ employees    Company - Public (FB)
# 4           10000+ employees    Company - Public (FB)
# ..                       ...                      ...
# 484         10000+ employees  Company - Public (AMZN)
# 485  5001 to 10000 employees                     1994
# 486         10000+ employees   Company - Public (LMT)
# 487         10000+ employees   Company - Public (LMT)
# 488         10000+ employees   Company - Public (LMT)
#
#                                    industry                           revenue  \
# 0                                        -1                                -1
# 1    Transportation Equipment Manufacturing   $2 to $5 billion (CAD) per year
# 2    Transportation Equipment Manufacturing   $2 to $5 billion (CAD) per year
# 3                                  Internet  $5 to $10 billion (CAD) per year
# 4                                  Internet       $10+ billion (CAD) per year
# ..                                      ...                               ...
# 484                                Internet       $10+ billion (CAD) per year
# 485          Subsidiary or Business Segment                       Video Games
# 486                     Aerospace & Defence       $10+ billion (CAD) per year
# 487                     Aerospace & Defence       $10+ billion (CAD) per year
# 488                     Aerospace & Defence       $10+ billion (CAD) per year
#
#     company_rating recommend_to_a_friend ceo_approval interview_difficulty
# 0               -1                    -1           -1                  2.7
# 1              3.5                    59           75                  2.9
# 2              3.5                    59           75                  2.9
# 3              4.4                    90           94                  3.1
# 4              4.4                    90           94                  3.1
# ..             ...                   ...          ...                  ...
# 484            3.9                    77           85                    3
# 485            3.7                    75           73                  2.7
# 486            3.9                    78           96                  2.6
# 487            3.9                    78           96                  2.6
# 488            3.9                    78           96                  2.6
#
# [489 rows x 17 columns]

# %%
-drop duplicate rows
-enter missing salary data 
-identical descriptions?
-identical skills?
-identical details?
-missing values glass door data
-format salary and do conversions 
-might not need details column?
